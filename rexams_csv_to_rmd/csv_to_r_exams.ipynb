# %%
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20744/497445485.py in <module>
#     273 #scope = 'k3' # this is an `exname`
#     274 from IPython.display import display
# --> 275 display(csv_to_r_exams(csv_file_name, False, True))
#     276
#     277 #help(csv_to_r_exams)
#
# ~\AppData\Local\Temp/ipykernel_20744/497445485.py in csv_to_r_exams(csv_file_name, scope, hints)
#     262         write_to_file(index)
#     263     import pandas as pd
# --> 264     df = pd.DataFrame(create_df_with_given_scope_from_csv(csv_file_name, scope))
#     265     for single_index in df.index:
#     266         write_single_question_to_Rmd(csv_file_name, single_index)
#
# ~\AppData\Local\Temp/ipykernel_20744/497445485.py in create_df_with_given_scope_from_csv(csv_file_name, scope)
#      37         import pandas as pd # reminder `pip install pandas`
# ...
